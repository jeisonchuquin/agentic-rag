# %% [markdown]
# **Teste de recuaperación de documentos de base vectorial**
#
# Seteamos rutas para importación de modulos

# %%
import os
import sys
os.chdir('..')
sys.path.append(os.getcwd())

# %% [markdown]
# Llamamos al retriever de la base vectorial.
#
# La base está originada en `src/infrastructure/chunking_doc.py`

# %%
from src.infrastructure.retrievers import retriever

# %%
QUESTION = 'notas para aprobar una materia'
retrieved_docs = retriever.invoke(QUESTION)

# %% [markdown]
# Temas principales recuperados

# %%
for pos, doc in enumerate(retrieved_docs):
    print(f'TOP: {pos + 1}: ', doc.metadata['Header_2'])
# Out:
# TOP: 1:  CALIFICACIÓN MÍNIMA PARA APROBACIÓN DE CURSOS DE ESPECIALIZACIÓN O CURSOS CON COMPONENTES PRÁCTICOS
# TOP: 2:  CALIFICACIÓN MÍNIMA PARA APROBACIÓN DE CURSOS DE COLEGIO GENERAL Y CURSOS DE INGLÉS U OTROS IDIOMAS, NOTAS 'D' PERMITIDAS EN MATERIAS DE COLEGIO GENERAL
# TOP: 3:  Valoración de la nota
# TOP: 4:  SIGNIFICADO DE LA NOTA
# TOP: 5:  CAMBIO DE NOTA
# TOP: 6:  CAMBIO Y APELACIÓN DE NOTA
# TOP: 7:  PROCESO ESPECIAL DE CAMBIO DE NOTA
# TOP: 8:  Pagos relacionados con la materia final
# TOP: 9:  EXÁMENES/TRABAJOS, RETROALIMENTACIÓN Y LIBRO DE NOTAS
# TOP: 10:  ELIMINACIÓN DE MATERIAS

# %% [markdown]
# Contenido de cada tema

# %%
for pos, doc in enumerate(retrieved_docs):
    print(50*'-----------------')
    print(f'TOP: {pos + 1}: ', doc.page_content)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...

# %%
QUESTION = 'fundador de la universidad san francisco de quito'
retrieved_docs = retriever.invoke(QUESTION)

# %%
for pos, doc in enumerate(retrieved_docs):
    print(f'TOP: {pos + 1}: ', doc.metadata['Header_2'])
# Out:
# TOP: 1:  CONSEJO DE REGENTES
# TOP: 2:  MISIÓN
# TOP: 3:  VISIÓN
# TOP: 4:  LA UNIVERSIDAD SAN FRANCISCO DE QUITO USFQ
# TOP: 5:  RECTORADO
# TOP: 6:  DECANATO DE INVESTIGACIÓN
# TOP: 7:  CONSEJO UNIVERSITARIO CU
# TOP: 8:  CAMPUS USFQ
# TOP: 9:  PROGRAMA DEL ADULTO
# TOP: 10:  LA RAZÓN DE UN CÓDIGO DE HONOR Y CONVIVENCIA

# %%
for pos, doc in enumerate(retrieved_docs):
    print(50*'-----------------')
    print(f'TOP: {pos + 1}: ', doc.page_content)
# Out:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ...
